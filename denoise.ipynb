# %%
import os
import numpy as np
from scipy.stats import poisson
import cv2
import matplotlib.pyplot as plt

def psnr(original, noisy):
    mse = np.mean((original - noisy) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 255.0
    psnr_value = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr_value

def ssim(original, noisy):
    C1 = (0.01 * 255) ** 2
    C2 = (0.03 * 255) ** 2

    original = original.astype(np.float64)
    noisy = noisy.astype(np.float64)

    kernel = cv2.getGaussianKernel(11, 1.5)
    window = np.outer(kernel, kernel.transpose())

    mu1 = cv2.filter2D(original, -1, window)[5:-5, 5:-5]
    mu2 = cv2.filter2D(noisy, -1, window)[5:-5, 5:-5]
    mu1_sq = mu1 ** 2
    mu2_sq = mu2 ** 2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = cv2.filter2D(original ** 2, -1, window)[5:-5, 5:-5] - mu1_sq
    sigma2_sq = cv2.filter2D(noisy ** 2, -1, window)[5:-5, 5:-5] - mu2_sq
    sigma12 = cv2.filter2D(original * noisy, -1, window)[5:-5, 5:-5] - mu1_mu2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))
    ssim_value = ssim_map.mean()

    return ssim_value

def add_poisson_gaussian_noise(image, sigma_read, total_gain, noise_scale=1.0, poisson_scale=1.0):
    image = np.clip(image.astype(np.float32) / 255.0, 0.0, 1.0)
    channels = np.split(image, 3, axis=2)

    noisy_channels = []
    for channel in channels:
        photon_counts = channel * total_gain
        shot_noise = poisson.rvs(photon_counts) / total_gain
        shot_noise *= poisson_scale
        read_noise = np.random.normal(loc=0.0, scale=sigma_read, size=channel.shape)
        noisy_channel = shot_noise + read_noise * noise_scale
        noisy_channels.append(noisy_channel)

    noisy_image = np.clip(np.dstack(noisy_channels), 0.0, 1.0)
    return (noisy_image * 255).astype(np.uint8)

def add_salt_and_pepper_noise(image, salt_prob, pepper_prob):
    noisy_image = np.copy(image)
    num_salt = np.ceil(salt_prob * image.size)
    num_pepper = np.ceil(pepper_prob * image.size)

    # Add salt noise
    coords = [np.random.randint(0, i - 1, int(num_salt)) for i in image.shape]
    noisy_image[coords[0], coords[1], :] = 255

    # Add pepper noise
    coords = [np.random.randint(0, i - 1, int(num_pepper)) for i in image.shape]
    noisy_image[coords[0], coords[1], :] = 0

    return noisy_image

def add_combined_noise(image, sigma_read, total_gain, noise_scale, poisson_scale, salt_prob, pepper_prob):
    noisy_image = add_poisson_gaussian_noise(image, sigma_read, total_gain, noise_scale, poisson_scale)
    noisy_image = add_salt_and_pepper_noise(noisy_image, salt_prob, pepper_prob)
    return noisy_image

# Set parameters
sigma_read = 0.1
total_gain = 500.0
noise_scale = 5.0
poisson_scale = 2.0
salt_prob = 0.02
pepper_prob = 0.02

dataset_folder = "C:\\Users\\VINUTHA R\\Desktop\\Data"
plot_count = 0
max_plots = 5

for root, _, files in os.walk(dataset_folder):
    for file in files:
        if file.startswith('GT_SRGB_010') and file.endswith('.PNG'):
            image_path = os.path.join(root, file)
            image = cv2.imread(image_path)

            # Add noise
            noisy_image = add_combined_noise(image, sigma_read, total_gain, noise_scale, poisson_scale, salt_prob, pepper_prob)

            # Calculate PSNR and SSIM
            psnr_value = psnr(image, noisy_image)
            ssim_value = ssim(image, noisy_image)

            print(f"Processing {image_path}")
            print(f"PSNR: {psnr_value:.2f} dB")
            print(f"SSIM: {ssim_value:.4f}")

            if plot_count < max_plots:
                # Plot results
                fig, axes = plt.subplots(1, 2, figsize=(10, 5))
                axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
                axes[0].set_title('Original')
                axes[0].axis('off')
                axes[1].imshow(cv2.cvtColor(noisy_image, cv2.COLOR_BGR2RGB))
                axes[1].set_title('Noisy')
                axes[1].axis('off')

                # Show and save plot
                plt.show()
                plot_count += 1

            # Save the noisy image
            output_path = os.path.join(root, f"noisy_{file}")
            cv2.imwrite(output_path, noisy_image)

            # Stop if max_plots is reached
            if plot_count >= max_plots:
                break
    if plot_count >= max_plots:
        break
# Out:
# Processing C:\Users\VINUTHA R\Desktop\Data\0001_001_S6_00100_00060_3200_L\GT_SRGB_010.PNG
# PSNR: 27.76 dB
# SSIM: 0.0060
# Processing C:\Users\VINUTHA R\Desktop\Data\0001_001_S6_00100_00060_3200_L\NOISY_SRGB_010.PNG
# PSNR: 27.79 dB
# SSIM: 0.0131
# Processing C:\Users\VINUTHA R\Desktop\Data\0002_001_S6_00100_00020_3200_N\GT_SRGB_010.PNG
# PSNR: 28.16 dB
# SSIM: 0.0094
# Processing C:\Users\VINUTHA R\Desktop\Data\0002_001_S6_00100_00020_3200_N\NOISY_SRGB_010.PNG
# PSNR: 28.13 dB
# SSIM: 0.0156
# Processing C:\Users\VINUTHA R\Desktop\Data\0003_001_S6_00100_00060_3200_H\GT_SRGB_010.PNG
# PSNR: 28.00 dB
# SSIM: 0.0236

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, AveragePooling2D, Add, Activation, Reshape, GlobalAveragePooling2D, Multiply
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# Function to load images from a directory and convert them to numpy arrays
def load_images_from_directory(directory, target_size=(256, 256), keyword='noisy_srgb'):
    images = []
    print(f"Loading images from directory: {directory} with keyword: {keyword}")
    try:
        filenames = os.listdir(directory)
        print(f"Found {len(filenames)} files in the directory.")
        for filename in filenames:
            # Adjust the condition to match your filenames for noisy images
            if keyword in filename.lower() and filename.lower().endswith((".jpg", ".png")):
                print(f"Processing file: {filename}")
                img_path = os.path.join(directory, filename)
                img = Image.open(img_path).resize(target_size)
                img_array = np.array(img)
                images.append(img_array)
            else:
                print(f"Skipping file (unsupported format or does not contain keyword): {filename}")
    except Exception as e:
        print(f"Error reading directory: {e}")
    return np.array(images)

# Function to traverse the main directory and process subfolders
def process_dataset(main_directory, keyword='noisy_srgb', target_size=(256, 256)):
    all_images = []
    subfolders = [f.path for f in os.scandir(main_directory) if f.is_dir()]
    print(f"Found {len(subfolders)} subfolders in the directory: {main_directory}")
    for subfolder in subfolders:
        print(f"Processing subfolder: {subfolder}")
        images = load_images_from_directory(subfolder, target_size, keyword)
        print(f"Loaded {len(images)} images from subfolder: {subfolder}")
        all_images.extend(images)
    return np.array(all_images)

# Paths to your image directories
main_train_directory = r"C:\Users\VINUTHA R\Desktop\Data"  # Use raw string for Windows path
main_test_directory = r"C:\Users\VINUTHA R\Desktop\Data"

X_train_patches = process_dataset(main_train_directory, keyword='noisy_srgb')
y_train_patches = X_train_patches  # For autoencoder, the output is the same as input

X_test_patches = process_dataset(main_test_directory, keyword='noisy_srgb')
y_test_patches = X_test_patches

# Now you can use X_train_patches and y_train_patches with your model
print(f"Loaded {len(X_train_patches)} training images.")
print(f"Loaded {len(X_test_patches)} test images.")
# Out:
# Found 160 subfolders in the directory: C:\Users\VINUTHA R\Desktop\Data
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0001_001_S6_00100_00060_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0001_001_S6_00100_00060_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0001_001_S6_00100_00060_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0002_001_S6_00100_00020_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0002_001_S6_00100_00020_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0002_001_S6_00100_00020_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0003_001_S6_00100_00060_3200_H
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0003_001_S6_00100_00060_3200_H with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0003_001_S6_00100_00060_3200_H
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0004_001_S6_00100_00060_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0004_001_S6_00100_00060_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0004_001_S6_00100_00060_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0005_001_S6_00100_00060_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0005_001_S6_00100_00060_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0005_001_S6_00100_00060_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0006_001_S6_00100_00060_4400_H
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0006_001_S6_00100_00060_4400_H with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0006_001_S6_00100_00060_4400_H
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0007_001_S6_00100_00100_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0007_001_S6_00100_00100_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0007_001_S6_00100_00100_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0008_001_S6_00100_00100_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0008_001_S6_00100_00100_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0008_001_S6_00100_00100_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0010_001_S6_00800_00350_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0010_001_S6_00800_00350_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0010_001_S6_00800_00350_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0011_001_S6_00800_00500_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0011_001_S6_00800_00500_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0011_001_S6_00800_00500_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0012_001_S6_00800_00500_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0012_001_S6_00800_00500_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0012_001_S6_00800_00500_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0013_001_S6_03200_01250_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0013_001_S6_03200_01250_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0013_001_S6_03200_01250_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0014_001_S6_03200_01250_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0014_001_S6_03200_01250_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0014_001_S6_03200_01250_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0015_001_S6_03200_01600_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0015_001_S6_03200_01600_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0015_001_S6_03200_01600_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0016_001_S6_03200_01600_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0016_001_S6_03200_01600_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0016_001_S6_03200_01600_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0017_001_GP_00100_00060_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0017_001_GP_00100_00060_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0017_001_GP_00100_00060_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0018_001_GP_00100_00160_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0018_001_GP_00100_00160_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0018_001_GP_00100_00160_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0019_001_GP_00800_00640_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0019_001_GP_00800_00640_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0019_001_GP_00800_00640_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0020_001_GP_00800_00350_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0020_001_GP_00800_00350_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0020_001_GP_00800_00350_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0022_001_N6_00100_00060_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0022_001_N6_00100_00060_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0022_001_N6_00100_00060_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0023_001_N6_00800_00350_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0023_001_N6_00800_00350_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0023_001_N6_00800_00350_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0025_001_G4_00100_00060_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0025_001_G4_00100_00060_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0025_001_G4_00100_00060_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0027_001_G4_00800_00350_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0027_001_G4_00800_00350_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0027_001_G4_00800_00350_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0028_001_IP_00100_00160_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0028_001_IP_00100_00160_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0028_001_IP_00100_00160_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0029_001_IP_00800_01000_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0029_001_IP_00800_01000_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0029_001_IP_00800_01000_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0030_001_IP_01600_02000_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0030_001_IP_01600_02000_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0030_001_IP_01600_02000_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0032_001_IP_00800_01000_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0032_001_IP_00800_01000_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0032_001_IP_00800_01000_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0033_001_IP_00100_00160_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0033_001_IP_00100_00160_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0033_001_IP_00100_00160_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0034_002_GP_00100_00160_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0034_002_GP_00100_00160_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0034_002_GP_00100_00160_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0035_002_GP_00800_00350_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0035_002_GP_00800_00350_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0035_002_GP_00800_00350_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0036_002_GP_06400_03200_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0036_002_GP_06400_03200_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0036_002_GP_06400_03200_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0038_002_GP_00800_00640_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0038_002_GP_00800_00640_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0038_002_GP_00800_00640_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0039_002_IP_00100_00180_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0039_002_IP_00100_00180_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0039_002_IP_00100_00180_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0040_002_IP_00800_02000_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0040_002_IP_00800_02000_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0040_002_IP_00800_02000_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0042_002_IP_01600_03100_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0042_002_IP_01600_03100_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0042_002_IP_01600_03100_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0043_002_IP_00800_01520_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0043_002_IP_00800_01520_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0043_002_IP_00800_01520_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0044_002_IP_00100_00180_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0044_002_IP_00100_00180_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0044_002_IP_00100_00180_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0045_002_G4_00100_00060_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0045_002_G4_00100_00060_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0045_002_G4_00100_00060_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0047_002_G4_00800_00640_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0047_002_G4_00800_00640_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0047_002_G4_00800_00640_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0048_002_N6_00100_00100_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0048_002_N6_00100_00100_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0048_002_N6_00100_00100_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0050_002_N6_03200_03200_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0050_002_N6_03200_03200_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0050_002_N6_03200_03200_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0051_002_S6_00100_00060_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0051_002_S6_00100_00060_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0051_002_S6_00100_00060_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0052_002_S6_01600_01000_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0052_002_S6_01600_01000_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0052_002_S6_01600_01000_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0054_003_N6_00100_00160_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0054_003_N6_00100_00160_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0054_003_N6_00100_00160_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0055_003_N6_00800_01000_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0055_003_N6_00800_01000_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0055_003_N6_00800_01000_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0057_003_G4_00100_00125_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0057_003_G4_00100_00125_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0057_003_G4_00100_00125_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0059_003_G4_00800_01000_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0059_003_G4_00800_01000_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0059_003_G4_00800_01000_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0060_003_S6_00100_00100_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0060_003_S6_00100_00100_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0060_003_S6_00100_00100_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0062_003_S6_03200_02500_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0062_003_S6_03200_02500_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0062_003_S6_03200_02500_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0063_003_GP_00100_00100_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0063_003_GP_00100_00100_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0063_003_GP_00100_00100_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0064_003_GP_01600_01600_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0064_003_GP_01600_01600_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0064_003_GP_01600_01600_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0065_003_GP_10000_08460_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0065_003_GP_10000_08460_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0065_003_GP_10000_08460_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0066_003_GP_00100_00200_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0066_003_GP_00100_00200_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0066_003_GP_00100_00200_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0068_003_IP_00200_00400_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0068_003_IP_00200_00400_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0068_003_IP_00200_00400_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0069_003_IP_01000_02000_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0069_003_IP_01000_02000_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0069_003_IP_01000_02000_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0070_003_IP_02000_04000_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0070_003_IP_02000_04000_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0070_003_IP_02000_04000_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0072_003_IP_01000_02000_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0072_003_IP_01000_02000_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0072_003_IP_01000_02000_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0073_003_IP_00200_01000_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0073_003_IP_00200_01000_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0073_003_IP_00200_01000_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0075_004_N6_00800_00080_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0075_004_N6_00800_00080_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0075_004_N6_00800_00080_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0076_004_N6_03200_00320_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0076_004_N6_03200_00320_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0076_004_N6_03200_00320_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0077_004_G4_00100_00025_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0077_004_G4_00100_00025_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0077_004_G4_00100_00025_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0078_004_G4_00200_00050_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0078_004_G4_00200_00050_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0078_004_G4_00200_00050_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0080_004_S6_00200_00050_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0080_004_S6_00200_00050_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0080_004_S6_00200_00050_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0081_004_S6_00800_00160_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0081_004_S6_00800_00160_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0081_004_S6_00800_00160_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0083_004_GP_00050_00020_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0083_004_GP_00050_00020_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0083_004_GP_00050_00020_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0084_004_GP_00200_00100_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0084_004_GP_00200_00100_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0084_004_GP_00200_00100_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0086_004_GP_00100_00100_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0086_004_GP_00100_00100_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0086_004_GP_00100_00100_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0087_004_GP_00800_00640_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0087_004_GP_00800_00640_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0087_004_GP_00800_00640_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0088_004_IP_00100_00050_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0088_004_IP_00100_00050_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0088_004_IP_00100_00050_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0089_004_IP_00500_00250_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0089_004_IP_00500_00250_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0089_004_IP_00500_00250_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0090_004_IP_01600_00750_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0090_004_IP_01600_00750_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0090_004_IP_01600_00750_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0091_004_IP_00320_00080_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0091_004_IP_00320_00080_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0091_004_IP_00320_00080_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0092_004_IP_00640_00125_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0092_004_IP_00640_00125_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0092_004_IP_00640_00125_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0094_005_N6_00100_00050_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0094_005_N6_00100_00050_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0094_005_N6_00100_00050_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0096_005_N6_01600_01000_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0096_005_N6_01600_01000_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0096_005_N6_01600_01000_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0097_005_N6_03200_02000_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0097_005_N6_03200_02000_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0097_005_N6_03200_02000_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0098_005_G4_00100_00050_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0098_005_G4_00100_00050_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0098_005_G4_00100_00050_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0099_005_G4_00400_00200_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0099_005_G4_00400_00200_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0099_005_G4_00400_00200_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0101_005_S6_00100_00050_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0101_005_S6_00100_00050_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0101_005_S6_00100_00050_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0102_005_S6_00400_00200_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0102_005_S6_00400_00200_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0102_005_S6_00400_00200_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0104_005_S6_03200_01600_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0104_005_S6_03200_01600_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0104_005_S6_03200_01600_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0105_005_GP_00100_00100_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0105_005_GP_00100_00100_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0105_005_GP_00100_00100_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0106_005_GP_00400_00400_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0106_005_GP_00400_00400_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0106_005_GP_00400_00400_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0107_005_GP_01600_01600_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0107_005_GP_01600_01600_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0107_005_GP_01600_01600_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0108_005_GP_06400_06400_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0108_005_GP_06400_06400_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0108_005_GP_06400_06400_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0110_005_IP_00100_00100_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0110_005_IP_00100_00100_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0110_005_IP_00100_00100_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0111_005_IP_00400_00400_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0111_005_IP_00400_00400_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0111_005_IP_00400_00400_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0113_005_IP_01600_01520_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0113_005_IP_01600_01520_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0113_005_IP_01600_01520_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0114_005_IP_00100_00200_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0114_005_IP_00100_00200_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0114_005_IP_00100_00200_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0115_005_IP_00400_00750_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0115_005_IP_00400_00750_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0115_005_IP_00400_00750_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0116_005_IP_00800_01520_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0116_005_IP_00800_01520_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0116_005_IP_00800_01520_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0117_005_IP_01600_04160_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0117_005_IP_01600_04160_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0117_005_IP_01600_04160_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0118_006_N6_00100_00025_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0118_006_N6_00100_00025_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0118_006_N6_00100_00025_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0120_006_N6_01600_00400_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0120_006_N6_01600_00400_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0120_006_N6_01600_00400_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0121_006_N6_03200_01000_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0121_006_N6_03200_01000_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0121_006_N6_03200_01000_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0122_006_G4_00100_00050_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0122_006_G4_00100_00050_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0122_006_G4_00100_00050_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0123_006_G4_00400_00160_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0123_006_G4_00400_00160_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0123_006_G4_00400_00160_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0125_006_S6_00100_00050_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0125_006_S6_00100_00050_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0125_006_S6_00100_00050_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0126_006_S6_00400_00200_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0126_006_S6_00400_00200_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0126_006_S6_00400_00200_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0127_006_S6_01600_00800_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0127_006_S6_01600_00800_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0127_006_S6_01600_00800_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0129_006_GP_00100_00100_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0129_006_GP_00100_00100_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0129_006_GP_00100_00100_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0130_006_GP_00400_00400_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0130_006_GP_00400_00400_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0130_006_GP_00400_00400_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0132_006_GP_00100_00200_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0132_006_GP_00100_00200_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0132_006_GP_00100_00200_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0133_006_GP_00800_01600_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0133_006_GP_00800_01600_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0133_006_GP_00800_01600_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0134_006_IP_00100_00100_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0134_006_IP_00100_00100_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0134_006_IP_00100_00100_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0135_006_IP_00400_00400_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0135_006_IP_00400_00400_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0135_006_IP_00400_00400_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0136_006_IP_00800_00800_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0136_006_IP_00800_00800_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0136_006_IP_00800_00800_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0137_006_IP_01600_01600_5500_N
# ...
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0159_007_IP_00100_00100_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0160_007_IP_00400_00400_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0160_007_IP_00400_00400_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0160_007_IP_00400_00400_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0161_007_IP_00800_00800_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0161_007_IP_00800_00800_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0161_007_IP_00800_00800_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0163_007_IP_00100_00100_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0163_007_IP_00100_00100_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0163_007_IP_00100_00100_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0164_007_IP_00400_00400_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0164_007_IP_00400_00400_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0164_007_IP_00400_00400_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0165_007_IP_00800_00800_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0165_007_IP_00800_00800_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0165_007_IP_00800_00800_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0166_007_IP_01600_01600_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0166_007_IP_01600_01600_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0166_007_IP_01600_01600_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0167_008_N6_00100_00050_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0167_008_N6_00100_00050_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0167_008_N6_00100_00050_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0168_008_N6_00400_00200_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0168_008_N6_00400_00200_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0168_008_N6_00400_00200_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0169_008_N6_00800_00400_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0169_008_N6_00800_00400_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0169_008_N6_00800_00400_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0170_008_N6_01600_00800_4400_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0170_008_N6_01600_00800_4400_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0170_008_N6_01600_00800_4400_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0172_008_G4_00100_00100_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0172_008_G4_00100_00100_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0172_008_G4_00100_00100_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0173_008_G4_00400_00400_4400_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0173_008_G4_00400_00400_4400_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0173_008_G4_00400_00400_4400_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0175_008_S6_00100_00025_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0175_008_S6_00100_00025_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0175_008_S6_00100_00025_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0177_008_S6_00800_00200_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0177_008_S6_00800_00200_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0177_008_S6_00800_00200_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0178_008_S6_01600_00400_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0178_008_S6_01600_00400_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0178_008_S6_01600_00400_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0179_008_S6_03200_00800_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0179_008_S6_03200_00800_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0179_008_S6_03200_00800_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0180_008_GP_00100_00100_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0180_008_GP_00100_00100_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0180_008_GP_00100_00100_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0181_008_GP_00800_00800_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0181_008_GP_00800_00800_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0181_008_GP_00800_00800_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0182_008_GP_03200_03200_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0182_008_GP_03200_03200_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0182_008_GP_03200_03200_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0184_008_IP_00100_00100_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0184_008_IP_00100_00100_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0184_008_IP_00100_00100_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0185_008_IP_00400_00400_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0185_008_IP_00400_00400_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0185_008_IP_00400_00400_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0186_008_IP_00800_00800_3200_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0186_008_IP_00800_00800_3200_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0186_008_IP_00800_00800_3200_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0188_008_IP_00100_00100_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0188_008_IP_00100_00100_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0188_008_IP_00100_00100_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0189_008_IP_00400_00400_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0189_008_IP_00400_00400_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0189_008_IP_00400_00400_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0190_008_IP_00800_00800_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0190_008_IP_00800_00800_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0190_008_IP_00800_00800_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0191_008_IP_01600_01600_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0191_008_IP_01600_01600_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0191_008_IP_01600_01600_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0192_009_IP_00100_00200_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0192_009_IP_00100_00200_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0192_009_IP_00100_00200_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0193_009_IP_00800_02000_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0193_009_IP_00800_02000_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0193_009_IP_00800_02000_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0194_009_IP_01600_04000_3200_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0194_009_IP_01600_04000_3200_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0194_009_IP_01600_04000_3200_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0195_009_IP_01600_04000_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0195_009_IP_01600_04000_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0195_009_IP_01600_04000_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0196_009_IP_00800_02000_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0196_009_IP_00800_02000_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0196_009_IP_00800_02000_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0197_009_IP_00100_00200_5500_L
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0197_009_IP_00100_00200_5500_L with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0197_009_IP_00100_00200_5500_L
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0198_010_GP_00100_00200_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0198_010_GP_00100_00200_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0198_010_GP_00100_00200_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0199_010_GP_00800_01600_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0199_010_GP_00800_01600_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0199_010_GP_00800_01600_5500_N
# Processing subfolder: C:\Users\VINUTHA R\Desktop\Data\0200_010_GP_01600_03200_5500_N
# Loading images from directory: C:\Users\VINUTHA R\Desktop\Data\0200_010_GP_01600_03200_5500_N with keyword: noisy_srgb
# Found 2 files in the directory.
# Skipping file (unsupported format or does not contain keyword): GT_SRGB_010.PNG
# Processing file: NOISY_SRGB_010.PNG
# Loaded 1 images from subfolder: C:\Users\VINUTHA R\Desktop\Data\0200_010_GP_01600_03200_5500_N
# Loaded 160 training images.
# Loaded 160 test images.

# %%
from sklearn.model_selection import train_test_split
X_train_patches, X_test_patches = train_test_split(X_train_patches, test_size=0.2, random_state=42)
y_train_patches = X_train_patches  # For autoencoder, the output is the same as input
y_test_patches = X_test_patches

# Check shapes of loaded images
print(f"Train images shape: {X_train_patches.shape}")
print(f"Test images shape: {X_test_patches.shape}")

# Define the data loader class
class Dataloder(tf.keras.utils.Sequence):
    def __init__(self, X, y, batch_size=1, shuffle=False):
        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(X))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, i):
        batch_indexes = self.indexes[i * self.batch_size:(i + 1) * self.batch_size]
        batch_x = self.X[batch_indexes]
        batch_y = self.y[batch_indexes]
        return batch_x, batch_y

    def __len__(self):
        return len(self.indexes) // self.batch_size

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

batch_size = 2  
train_dataloader = Dataloder(X_train_patches, y_train_patches, batch_size, shuffle=True)
test_dataloader = Dataloder(X_test_patches, y_test_patches, batch_size, shuffle=False)

def show_batch(dataloader, batch_num=0):
    batch_x, batch_y = dataloader[batch_num]
    print(f"Batch {batch_num} - batch_x shape: {batch_x.shape}, batch_y shape: {batch_y.shape}")
    if len(batch_x) == 0:
        print("Empty batch!")
        return
    fig, axes = plt.subplots(1, len(batch_x), figsize=(15, 15))
    for img, ax in zip(batch_x, axes):
        ax.imshow(img.astype(np.uint8))
        ax.axis('off')
    plt.show()

show_batch(train_dataloader, batch_num=0)

# Build and compile the autoencoder model
tf.keras.backend.clear_session()
input = Input(shape=(256, 256, 3))

# Encoder
x = Conv2D(32, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(input)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Conv2D(64, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = MaxPooling2D((2, 2), padding="same")(x)
x = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = MaxPooling2D((2, 2), padding="same")(x)

# Decoder
x = Conv2DTranspose(128, (3, 3), strides=2, activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = Conv2DTranspose(64, (3, 3), strides=2, activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = Conv2DTranspose(32, (3, 3), strides=2, activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = Conv2D(3, (3, 3), activation="sigmoid", kernel_initializer='he_normal', padding="same")(x)

# Autoencoder
autoencoder = Model(input, x)
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(1e-03), loss=tf.keras.losses.MeanSquaredError())

# Fit the autoencoder model
autoencoder.fit(train_dataloader, epochs=1)
# Out:
# Train images shape: (128, 256, 256, 3)
# Test images shape: (32, 256, 256, 3)
# Batch 0 - batch_x shape: (2, 256, 256, 3), batch_y shape: (2, 256, 256, 3)
# WARNING:tensorflow:From c:\Users\VINUTHA R\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\common\global_state.py:73: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# c:\Users\VINUTHA R\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 23s 246ms/step - loss: 7586.6099

# %%
tf.keras.backend.clear_session()
input = Input(shape=(256, 256, 3))

#Noise estimation subnetwork
x = Conv2D(32, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(input)
x = Conv2D(32, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = Conv2D(32, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = Conv2D(32, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)
x = Conv2D(3, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)

#Non Blind denoising subnetwork
x = concatenate([x, input])
conv1 = Conv2D(64, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(x)
conv2 = Conv2D(64, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv1)

pool1 = AveragePooling2D(pool_size=(2, 2), padding='same')(conv2)
conv3 = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(pool1)
conv4 = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv3)
conv5 = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv4)

pool2 = AveragePooling2D(pool_size=(2, 2), padding='same')(conv5)
conv6 = Conv2D(256, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(pool2)
conv7 = Conv2D(256, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv6)
conv8 = Conv2D(256, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv7)
conv9 = Conv2D(256, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv8)
conv10 = Conv2D(256, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv9)
conv11 = Conv2D(256, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv10)

upsample1 = Conv2DTranspose(128, (3, 3), strides=2, activation="relu", kernel_initializer='he_normal', padding="same")(conv11)
add1 = Add()([upsample1, conv5])
conv12 = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(add1)
conv13 = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv12)
conv14 = Conv2D(128, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv13)

upsample2 = Conv2DTranspose(64, (3, 3), strides=2, activation="relu", kernel_initializer='he_normal', padding="same")(conv14)
add1 = Add()([upsample2, conv2])
conv15 = Conv2D(64, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(add1)
conv16 = Conv2D(64, (3, 3), activation="relu", kernel_initializer='he_normal', padding="same")(conv15)

out = Conv2D(3, (1, 1), kernel_initializer='he_normal', padding="same")(conv16)
out = Add()([out, input])

CBDNet = Model(input, out)
CBDNet.compile(optimizer=tf.keras.optimizers.Adam(1e-03), loss=tf.keras.losses.MeanSquaredError())

#Fit the CBDNet model
CBDNet.fit(train_dataloader, epochs=1)

#Define the EAM layer class
class EAM(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.conv1 = Conv2D(64, (3, 3), dilation_rate=1, padding='same', activation='relu')
        self.conv2 = Conv2D(64, (3, 3), dilation_rate=2, padding='same', activation='relu')
        self.conv3 = Conv2D(64, (3, 3), dilation_rate=3, padding='same', activation='relu')
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 277s 4s/step - loss: 2145.1831

# %%
denoised_images = CBDNet.predict(X_test_patches)

# Function to display images
def display_images(original, denoised, num_images=1):
    plt.figure(figsize=(20, 4))
    for i in range(num_images):
        # Display original noisy image
        ax = plt.subplot(2, num_images, i + 1)
        plt.imshow(original[i].astype(np.uint8))
        plt.title("Noisy")
        plt.axis("off")

        # Display denoised image
        ax = plt.subplot(2, num_images, i + 1 + num_images)
        plt.imshow(denoised[i].astype(np.uint8))
        plt.title("Denoised")
        plt.axis("off")

    plt.show()

# Normalize the test images to [0, 1] range before prediction if not already done
test_images_normalized = X_test_patches / 255.0

# Generate denoised images
denoised_images = CBDNet.predict(test_images_normalized)

# Rescale denoised images back to [0, 255] range if necessary
denoised_images = denoised_images * 255.0
denoised_images = np.clip(denoised_images, 0, 255).astype(np.uint8)

# Display a few examples
display_images(X_test_patches, denoised_images)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
